# %%
import pandas as pd
        
emod_infection_summary_gametocytes = pd.read_csv('../../network_sim/emod_infection_summary_gametocytes.csv')
emod_infection_summary_gametocytes
# Out:
#      duration_bin log10_total_gametocyte_density_bin      prob  \
# 0      (135, 140]                         (3.6, 3.7]  0.003236
# 1      (140, 145]                         (3.5, 3.6]  0.009709
# 2      (145, 150]                         (3.4, 3.5]  0.003236
# 3      (145, 150]                         (3.5, 3.6]  0.012945
# 4      (150, 155]                         (3.0, 3.1]  0.003236
# ...           ...                                ...       ...
# 6034   (195, 200]                         (2.1, 2.2]  0.000353
# 6035   (195, 200]                         (2.4, 2.5]  0.000353
# 6036   (200, 205]                         (1.3, 1.4]  0.000353
# 6037   (200, 205]                         (2.3, 2.4]  0.000707
# 6038   (270, 275]                         (0.6, 0.7]  0.000353
#
#       duration_bin_min  duration_bin_max  \
# 0                  135               140
# 1                  140               145
# 2                  145               150
# ...

# %%
# print all unique values in immunity_bin
emod_infection_summary_gametocytes['immunity_bin'].unique()
# Out:
# array(['(-0.001, 0.05]', '(0.05, 0.1]', '(0.1, 0.15]', '(0.15, 0.2]',
#        '(0.2, 0.25]', '(0.25, 0.3]', '(0.3, 0.35]', '(0.35, 0.4]',
#        '(0.4, 0.45]', '(0.45, 0.5]', '(0.5, 0.55]', '(0.55, 0.6]',
#        '(0.6, 0.65]', '(0.65, 0.7]', '(0.7, 0.75]', '(0.75, 0.8]',
#        '(0.8, 0.85]', '(0.85, 0.9]', '(0.9, 0.95]', '(0.95, 1.0]'],
#       dtype=object)

# %%
# choose a middle bin
sdf = emod_infection_summary_gametocytes[emod_infection_summary_gametocytes['immunity_bin'] == (0.25, 0.3]
