# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("exp_id_1cc12931-2667-ef11-aa17-9440c9be2c51/sweep_data.csv")
df2 = pd.read_csv("exp_id_5ef8e9e3-2767-ef11-aa17-9440c9be2c51/sweep_data.csv")
df3 = pd.read_csv("exp_id_651e73d9-2967-ef11-aa17-9440c9be2c51/sweep_data.csv")
df4 = pd.read_csv("exp_id_9105fffe-2767-ef11-aa17-9440c9be2c51/sweep_data.csv")

# %%
df1.columns
# Out:
# Index(['sim_id', 'prev', 'mean_coi', 'polygenomic_frac',
#        'mean_within_host_ibs', 'mean_within_host_ibd', 'proportion_unique'],
#       dtype='object')

# %%
sorted(df4["prev"])
# Out:
# [0.0001,
#  0.003,
#  0.0192,
#  0.0423,
#  0.0504,
#  0.058,
#  0.0718,
#  0.0828,
#  0.0891,
#  0.0896,
#  0.0966,
#  0.0973,
#  0.0988,
#  0.0991,
#  0.0998,
#  0.0998,
#  0.0998,
#  0.0999,
#  0.1,
#  0.1,
#  0.1,
#  0.1]

# %%
plt.scatter(df1["prev"], df1["mean_coi"], label="10k, 3k days")
plt.scatter(df2["prev"]/10, df2["mean_coi"], label="100k, 3k days")
plt.scatter(df3["prev"], df3["mean_coi"], label="10k, 6k days")
plt.scatter(df4["prev"]*10, df4["mean_coi"], label="1k, 3k days")

plt.legend()
plt.xlabel("Prevalence")
plt.ylabel("Mean COI")
# Out:
# Text(0, 0.5, 'Mean COI')

# %%
plt.scatter(df1["prev"], df1["polygenomic_frac"], label="10k, 3k days")
plt.scatter(df2["prev"]/10, df2["polygenomic_frac"], label="100k, 3k days")
plt.scatter(df3["prev"], df3["polygenomic_frac"], label="10k, 6k days")
plt.scatter(df4["prev"]*10, df4["polygenomic_frac"], label="1k, 3k days")

plt.legend()
plt.xlabel("Prevalence")
plt.ylabel("Polygenomic Fraction")
# Out:
# Text(0, 0.5, 'Polygenomic Fraction')

# %%
plt.scatter(df1["prev"], df1["mean_within_host_ibs"], label="10k, 3k days")
plt.scatter(df2["prev"]/10, df2["mean_within_host_ibs"], label="100k, 3k days")
plt.scatter(df3["prev"], df3["mean_within_host_ibs"], label="10k, 6k days")
plt.scatter(df4["prev"]*10, df4["mean_within_host_ibs"], label="1k, 3k days")

plt.legend()
plt.xlabel("Prevalence")
plt.ylabel("Mean Within Host IBS")
# Out:
# Text(0, 0.5, 'Mean Within Host IBS')

# %%
plt.scatter(df1["prev"], df1["proportion_unique"], label="10k, 3k days")
plt.scatter(df2["prev"]/10, df2["proportion_unique"], label="100k, 3k days")
plt.scatter(df3["prev"], df3["proportion_unique"], label="10k, 6k days")
plt.scatter(df4["prev"]*10, df4["proportion_unique"], label="1k, 3k days")

plt.legend()
plt.xlabel("Prevalence")
plt.ylabel("proportion_unique")
# Out:
# Text(0, 0.5, 'proportion_unique')

# %%
plt.scatter(df1["prev"], df1["mean_within_host_ibd"], label="10k, 3k days")
plt.scatter(df2["prev"]/10, df2["mean_within_host_ibd"], label="100k, 3k days")
plt.scatter(df3["prev"], df3["mean_within_host_ibd"], label="10k, 6k days")
plt.scatter(df4["prev"]*10, df4["mean_within_host_ibd"], label="1k, 3k days")

plt.legend()
plt.xlabel("Prevalence")
plt.ylabel("Mean Within Host IBD")
# Out:
# Text(0, 0.5, 'Mean Within Host IBD')
