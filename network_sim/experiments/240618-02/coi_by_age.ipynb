# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_coi = pd.read_csv("coi.csv")
df_humans = pd.read_csv("human_lookup.csv")

# %%
df_coi = df_coi.merge(df_humans, on="human_id", how="left")

# %%
df_coi
# Out:
#       human_id  coi        age  biting_rate
# 0            1   11   0.001954          0.3
# 1            3    2   0.006451          0.3
# 2            4    1   0.007192          0.3
# 3            6    3   0.008549          0.3
# 4            7    7   0.010226          0.3
# ...        ...  ...        ...          ...
# 5798      9989    2  85.227977          0.3
# 5799      9991    4  87.082455          0.3
# 5800      9994    4  89.003711          0.3
# 5801      9995    5  89.594642          0.3
# 5802      9999    4  98.507598          0.3
#
# [5803 rows x 4 columns]

# %%
plt.scatter(df_coi["biting_rate"], df_coi["coi"],alpha=0.1)
plt.xscale("log")
# plt.yscale("log")

# %%
plt.scatter(df_coi["age"], df_coi["coi"],alpha=0.1)
