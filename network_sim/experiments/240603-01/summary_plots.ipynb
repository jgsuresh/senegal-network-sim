# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_context("talk")

# %%
df = pd.read_csv("outputs/coi_prev_polygenomic.csv")

# %%
df
# Out:
#                                   sim_id  prevalence  max_coi   mean_coi  \
# 0   129422ae-d921-ef11-aa14-b88303911bc1      0.3432    169.0   2.856061
# 1   139422ae-d921-ef11-aa14-b88303911bc1      0.3619    196.0   3.579442
# 2   149422ae-d921-ef11-aa14-b88303911bc1      0.3396    256.0   3.209069
# 3   159422ae-d921-ef11-aa14-b88303911bc1      0.3341    325.0   3.199641
# 4   179422ae-d921-ef11-aa14-b88303911bc1      0.5088    225.0   4.924921
# 5   189422ae-d921-ef11-aa14-b88303911bc1      0.0000      0.0   0.000000
# 6   199422ae-d921-ef11-aa14-b88303911bc1      0.5214    257.0   5.138473
# 7   1a9422ae-d921-ef11-aa14-b88303911bc1      0.0000      0.0   0.000000
# 8   1b9422ae-d921-ef11-aa14-b88303911bc1      0.5261    226.0   5.281125
# 9   1c9422ae-d921-ef11-aa14-b88303911bc1      0.0000      0.0   0.000000
# 10  1d9422ae-d921-ef11-aa14-b88303911bc1      0.5291    196.0   5.048762
# 11  1e9422ae-d921-ef11-aa14-b88303911bc1      0.0000      0.0   0.000000
# ...

# %%
plt.scatter(df["prevalence"], df["mean_coi"])
plt.xlim([0,1])
plt.xlabel("Prevalence")
plt.ylabel("Average COI")
# Out:
# Text(0, 0.5, 'Average COI')

# %%
plt.scatter(df["prevalence"], df["polygenomic_fraction"])
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel("Prevalence")
plt.ylabel("Polygenomic fraction")
# Out:
# Text(0, 0.5, 'Polygenomic fraction')
