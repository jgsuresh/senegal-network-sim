# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_coi = pd.read_csv("coi.csv")
df_humans = pd.read_csv("human_lookup.csv")

# %%
df_coi = df_coi.merge(df_humans, on="human_id", how="left")

# %%
df_coi
# Out:
#       human_id  coi        age  biting_rate
# 0            0    8   0.001430     0.744770
# 1            1    5   0.004120     0.376397
# 2            3    7   0.006984     0.227372
# 3            4    4   0.009804     0.662235
# 4            6    8   0.018122     0.221356
# ...        ...  ...        ...          ...
# 5388      9989    1  84.588863     0.143483
# 5389      9990    4  84.599885     0.539385
# 5390      9991    2  84.665556     0.124647
# 5391      9992   14  84.787196     0.376667
# 5392      9996    7  85.713867     0.197409
#
# [5393 rows x 4 columns]

# %%
plt.scatter(df_coi["biting_rate"], df_coi["coi"],alpha=0.1)
plt.xscale("log")
# plt.yscale("log")

# %%
plt.scatter(df_coi["age"], df_coi["coi"],alpha=0.1)
